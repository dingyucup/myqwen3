# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %ls
# Out:
# 'Colab Notebooks'/   mygpt_zh/   mygpt_zh_small/   myqwen3/   myqwen3.tar.gz

# %%
# !tar -zxvf myqwen3.tar.gz
# Out:
# ./myqwen3/
# ./myqwen3/pretrained/
# ./myqwen3/logs/
# ./myqwen3/.idea/
# ./myqwen3/.idea/inspectionProfiles/
# ./myqwen3/.idea/inspectionProfiles/profiles_settings.xml
# ./myqwen3/.idea/inspectionProfiles/Project_Default.xml
# ./myqwen3/.idea/modules.xml
# ./myqwen3/.idea/myqwen3.iml
# ./myqwen3/.idea/misc.xml
# ./myqwen3/.idea/.gitignore
# ./myqwen3/.idea/workspace.xml
# ./myqwen3/models/
# ./myqwen3/models/vocab.txt
# ./myqwen3/test/
# ./myqwen3/test/hello.py
# ./myqwen3/test/embedding.py
# ./myqwen3/test/test.ipynb
# ./myqwen3/test/embedding_test.py
# ./myqwen3/test/simple_tokenizer.py
# ./myqwen3/src/
# ./myqwen3/src/configuration/
# ./myqwen3/src/configuration/config.py
# ./myqwen3/src/configuration/__init__.py
# ./myqwen3/src/main.py
# ./myqwen3/src/predict/
# ./myqwen3/src/predict/predictor.py
# ./myqwen3/src/predict/__pycache__/
# ./myqwen3/src/predict/__pycache__/predictor.cpython-312.pyc
# ./myqwen3/src/predict/__pycache__/__init__.cpython-312.pyc
# ...

# %%
! cp mygpt_zh_small/data myqwen3/ -r

# %%
# %cd myqwen3
# Out:
# /content/drive/MyDrive/myqwen3

# %%
# %cd src/train/
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# %ls
# Out:
# __init__.py  trainer.py

# %%
# !python trainer.py
# Out:
# 2025-12-09 01:48:42.556940: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 01:48:42.573516: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765244922.594970     695 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765244922.601354     695 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd ..
# Out:
# /content/drive/My Drive/myqwen3/src

# %%
# %cd predict/
# Out:
# /content/drive/MyDrive/myqwen3/src/predict

# %%
# !python predictor.py
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.837 seconds.
# Prefix dict has been built successfully.
# [top-k采样]:我深情地望着她，而她又没有一个像我一样想要我的孩子那样渴望着能一遍遍地把自己从我的生活中引了出来；她的手几乎使我想起了自己的母亲的脸。一片黑暗中，我向她伸出一
# [贪心采样]:我深情地望着她，她的脸上泛起了红晕，她的脸上泛起了红晕，她的脸上泛起了红晕，她的脸上泛起了红晕，她的脸上泛起了红晕，她的脸上
