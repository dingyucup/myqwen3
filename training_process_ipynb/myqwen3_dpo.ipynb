# %%
# %cd drive/MyDrive/myqwen3/src/train/
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-27 13:19:32.915109: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-27 13:19:32.933120: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766841572.955236    9597 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766841572.961835    9597 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-27 13:50:37.853719: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-27 13:50:37.872721: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766843437.896273   17770 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766843437.903284   17770 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %ls
# Out:
# __init__.py       predictor_kv_cache.py  predictor_steam.py
# predictor_bak.py  predictor.py           __pycache__/

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-27 15:55:09.317556: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-27 15:55:09.336241: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766850909.359655   49461 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766850909.366510   49461 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd ../predict//
# Out:
# /content/drive/MyDrive/myqwen3/src/predict

# %%
# !python predictor_kv_cache.py
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.925 seconds.
# Prefix dict has been built successfully.
# Qwen3Model(
#   (token_embedding): Embedding(54806, 512)
#   (transformer_blocks): Sequential(
#     (0): TransformerBlock(
#       (attention): GroupQueryAttentionWithKVCache(
#         (attn): GroupQueryAttention(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=128, bias=False)
#           (W_value): Linear(in_features=512, out_features=128, bias=False)
#           (rope): RoPE()
#           (out_proj): Linear(in_features=512, out_features=512, bias=False)
#           (q_norm): RMSNorm()
#           (k_norm): RMSNorm()
#         )
#       )
#       (feedforward_network): MoEFeedForward(
#         (gate): Linear(in_features=512, out_features=16, bias=False)
#         (fc1): ModuleList(
# ...

# %%
# %cd ../utils/
# Out:
# /content/drive/MyDrive/myqwen3/src/utils

# %%
# !python merge_and_save_lora_model.py
# Out:
# 原始模型可训练的参数量：366,088,192
# LoRA模型可训练的参数量：303,612,256
# Qwen3Model(
#   (token_embedding): Embedding(54806, 512)
#   (transformer_blocks): Sequential(
#     (0): TransformerBlock(
#       (attention): GroupQueryAttention(
#         (W_query): Linear(in_features=512, out_features=512, bias=False)
#         (W_key): Linear(in_features=512, out_features=128, bias=False)
#         (W_value): Linear(in_features=512, out_features=128, bias=False)
#         (rope): RoPE()
#         (out_proj): Linear(in_features=512, out_features=512, bias=False)
#         (q_norm): RMSNorm()
#         (k_norm): RMSNorm()
#       )
#       (feedforward_network): MoEFeedForward(
#         (gate): Linear(in_features=512, out_features=16, bias=False)
#         (fc1): ModuleList(
#           (0-15): 16 x Linear(in_features=512, out_features=1024, bias=False)
#         )
#         (fc2): ModuleList(
#           (0-15): 16 x Linear(in_features=512, out_features=1024, bias=False)
#         )
# ...

# %%
# %cd ../train/
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-28 01:21:59.863461: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-28 01:21:59.881543: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766884919.903085   19164 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766884919.909792   19164 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd ../predict/
# Out:
# /content/drive/MyDrive/myqwen3/src/predict

# %%
# !python predictor_kv_cache.py
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.855 seconds.
# Prefix dict has been built successfully.
# Qwen3Model(
#   (token_embedding): Embedding(54806, 512)
#   (transformer_blocks): Sequential(
#     (0): TransformerBlock(
#       (attention): GroupQueryAttentionWithKVCache(
#         (attn): GroupQueryAttention(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=128, bias=False)
#           (W_value): Linear(in_features=512, out_features=128, bias=False)
#           (rope): RoPE()
#           (out_proj): Linear(in_features=512, out_features=512, bias=False)
#           (q_norm): RMSNorm()
#           (k_norm): RMSNorm()
#         )
#       )
#       (feedforward_network): MoEFeedForward(
#         (gate): Linear(in_features=512, out_features=16, bias=False)
#         (fc1): ModuleList(
# ...

# %%
# %cd drive/MyDrive/myqwen3/src/train
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# %ls
# Out:
# __init__.py  trainer_amp.py  trainer_dpo.py  trainer_lora.py  trainer.py

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-28 07:07:31.821964: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-28 07:07:31.838682: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766905651.859981    1918 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766905651.866428    1918 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd ../predict/
# Out:
# /content/drive/MyDrive/myqwen3/src/predict

# %%
# !python predictor_kv_cache.py
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.837 seconds.
# Prefix dict has been built successfully.
# Qwen3Model(
#   (token_embedding): Embedding(54806, 512)
#   (transformer_blocks): Sequential(
#     (0): TransformerBlock(
#       (attention): GroupQueryAttentionWithKVCache(
#         (attn): GroupQueryAttention(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=128, bias=False)
#           (W_value): Linear(in_features=512, out_features=128, bias=False)
#           (rope): RoPE()
#           (out_proj): Linear(in_features=512, out_features=512, bias=False)
#           (q_norm): RMSNorm()
#           (k_norm): RMSNorm()
#         )
#       )
#       (feedforward_network): MoEFeedForward(
#         (gate): Linear(in_features=512, out_features=16, bias=False)
#         (fc1): ModuleList(
# ...

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive/MyDrive/myqwen3/src/train
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# %cd ../train
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-28 12:17:15.536029: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-28 12:17:15.554490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766924235.576799   12405 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766924235.583598   12405 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/myqwen3/src

# %%
# %cd predict/
# Out:
# /content/drive/MyDrive/myqwen3/src/predict

# %%
# !python predictor_kv_cache.py
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.867 seconds.
# Prefix dict has been built successfully.
# Qwen3Model(
#   (token_embedding): Embedding(54806, 512)
#   (transformer_blocks): Sequential(
#     (0): TransformerBlock(
#       (attention): GroupQueryAttentionWithKVCache(
#         (attn): GroupQueryAttention(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=128, bias=False)
#           (W_value): Linear(in_features=512, out_features=128, bias=False)
#           (rope): RoPE()
#           (out_proj): Linear(in_features=512, out_features=512, bias=False)
#           (q_norm): RMSNorm()
#           (k_norm): RMSNorm()
#         )
#       )
#       (feedforward_network): MoEFeedForward(
#         (gate): Linear(in_features=512, out_features=16, bias=False)
#         (fc1): ModuleList(
# ...

# %%
# %cd drive/MyDrive/myqwen3/src/train
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-28 13:46:01.013481: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-28 13:46:01.030388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766929561.051637    4127 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766929561.058165    4127 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd ../predict
# Out:
# /content/drive/MyDrive/myqwen3/src/predict

# %%
# !python predictor_kv_cache.py
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.852 seconds.
# Prefix dict has been built successfully.
# Qwen3Model(
#   (token_embedding): Embedding(54806, 512)
#   (transformer_blocks): Sequential(
#     (0): TransformerBlock(
#       (attention): GroupQueryAttentionWithKVCache(
#         (attn): GroupQueryAttention(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=128, bias=False)
#           (W_value): Linear(in_features=512, out_features=128, bias=False)
#           (rope): RoPE()
#           (out_proj): Linear(in_features=512, out_features=512, bias=False)
#           (q_norm): RMSNorm()
#           (k_norm): RMSNorm()
#         )
#       )
#       (feedforward_network): MoEFeedForward(
#         (gate): Linear(in_features=512, out_features=16, bias=False)
#         (fc1): ModuleList(
# ...

# %%
# %cd ../train
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-28 15:09:06.170837: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-28 15:09:06.188792: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766934546.210546   26003 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766934546.217201   26003 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-28 16:25:28.552794: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-28 16:25:28.570735: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766939128.592254   45642 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766939128.598808   45642 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-29 16:39:43.580544: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-29 16:39:43.601084: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767026383.623230   13043 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767026383.631490   13043 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-29 17:11:10.570086: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-29 17:11:10.588794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767028270.610430   21292 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767028270.616972   21292 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-29 17:40:13.820767: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-29 17:40:13.840231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767030013.862432   28926 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767030013.869202   28926 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-30 05:40:43.505721: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-30 05:40:43.522604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767073243.543893    7049 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767073243.550386    7049 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-30 06:09:39.503049: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-30 06:09:39.520945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767074979.542495   14650 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767074979.549027   14650 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-30 06:39:50.384845: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-30 06:39:50.402158: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767076790.423514   22594 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767076790.429958   22594 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-30 07:10:49.142427: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-30 07:10:49.160204: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767078649.181476   30583 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767078649.187860   30583 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-30 12:55:54.828965: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-30 12:55:54.846351: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767099354.867717    4619 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767099354.874138    4619 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd drive/MyDrive/myqwen3/src/train/
# Out:
# /content/drive/MyDrive/myqwen3/src/train

# %%
# !python trainer_dpo.py
# Out:
# 2025-12-31 01:32:06.001904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767144726.034637   16375 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767144726.044253   16375 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767144726.069514   16375 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
